# %% [markdown]
# ### Die folgenden Beispiele geben einen ersten Einblick in die Möglichkeiten der Visualisierung von Daten mithilfe der Bibliothek matplotlib.
# Detaillierte Informationen zum Arbeiten mit matplotlib finden Sie z.B. unter folgenden Links:
#
# ##### https://matplotlib.org
# ##### https://seaborn.pydata.org/introduction.html
# ##### https://jakevdp.github.io/PythonDataScienceHandbook/
# ##### https://www.datacamp.com/community/tutorials/matplotlib-tutorial-python
# ##### https://github.com/rougier/matplotlib-tutorial

# %%
# importieren von matplotlib
import matplotlib.pyplot as plt

# %%
# ein erster einfacher Plot
plt.plot([1, 5, 9, 12, 5, 3, 8])
plt.show()

# %%
# nun der gleiche Plot mit anderer Darstellung
plt.plot([1, 5, 9, 12, 5, 3, 8],"o")
plt.show()

# %%
# jetzt doch lieber mit einer gestrichelten Linie
plt.plot([1, 5, 9, 12, 5, 3, 8], "--")
plt.show()

# %%
# und nun lieber in der Farbe magenta
plt.plot([1, 5, 9, 12, 5, 3, 8], "--m")
plt.show()

# %%
# nun mal zwei Datenreihen (x,y) plotten
monatstage = list(range(1,32))
# print(monatstage)
messwerte = [2,4,3,4,5,3,2,6,3,6,4,2,6,3,7,4,6,7,2,1,4,5,0,4,6,7,6,6,7,3,4]
plt.plot(monatstage, messwerte, "--m")
plt.show()

# %%
# nun spendieren wir mal eine Achsenbeschriftung
# nun mal zwei Datenreihen (x,y) plotten
monatstage = list(range(1,32))
# print(monatstage)
messwerte = [2,4,3,4,5,3,2,6,3,6,4,2,6,3,7,4,6,7,2,1,4,5,0,4,6,7,6,6,7,3,4]
plt.plot(monatstage, messwerte, "--m")
plt.xlabel("Tag des Monats")
plt.ylabel("Sonnenstunden")
plt.show()

# %%
# man kann auch mehrer Datenreihen in einem Diagramm darstellen
# nun spendieren wir mal eine Achsenbeschriftung
# nun mal zwei Datenreihen (x,y) plotten
monate = list(range(1,13))
regentage = [2,4,3,4,5,3,2,6,3,6,4,2]
niederschlagsmenge = [220,124,210,45,330,58,190,257,209,113,227,97]
plt.plot(monate, regentage, "--m", monate, niederschlagsmenge, "--b")
plt.xlabel("Tag des Monats")
plt.ylabel("Niederschlag Tage/Menge")
plt.show()

# %%
# eine weitere Möglichkeit der Formatierung 
#... viele Wege führen nach Rom
monate = list(range(1,13))
regentage = [2,4,3,4,5,3,2,6,3,6,4,2]
niederschlagsmenge = [220,124,210,45,330,58,190,257,209,113,227,97]
plt.plot(monate, regentage, color = "green", linewidth = 4.5, linestyle = "--")
plt.plot(monate, niederschlagsmenge, color = "blue", linewidth = 2, linestyle = "-")
plt.xlabel("Tag des Monats")
plt.ylabel("Niederschlag Tage/Menge")
plt.show()

# %%
# Flächen unter der Kurve einfärben
monate = list(range(1,13))
regentage = [2,4,3,4,5,3,2,6,3,6,4,2]
niederschlagsmenge = [220,124,210,45,330,58,190,257,209,113,227,97]
plt.plot(monate, regentage, color = "green", linewidth = 4.5, linestyle = "--")
plt.plot(monate, niederschlagsmenge, color = "blue", linewidth = 2, linestyle = "-")
plt.fill_between(monate, 0, niederschlagsmenge, color='blue', alpha=.4)
plt.xlabel("Tag des Monats")
plt.ylabel("Niederschlag Tage/Menge")
plt.show()

# %%
# ein Diagrammtitel fehlt noch
monate = list(range(1,13))
regentage = [2,4,3,4,5,3,2,6,3,6,4,2]
niederschlagsmenge = [220,124,210,45,330,58,190,257,209,113,227,97]
plt.plot(monate, regentage, color = "green", linewidth = 4.5, linestyle = "--")
plt.plot(monate, niederschlagsmenge, color = "blue", linewidth = 2, linestyle = "-")
plt.fill_between(monate, 0, niederschlagsmenge, color='blue', alpha=.1)
plt.xlabel("Tag des Monats")
plt.ylabel("Niederschlag Tage/Menge")
plt.title("mein Diagramm")
plt.show()

# %%
# Vorbereitung für das Plotten mehrerer Diragramme anordnen
gridsize = (3, 2)
fig = plt.figure(figsize=(12, 8))
ax1 = plt.subplot2grid(gridsize, (0, 0), colspan=2, rowspan=2)
ax2 = plt.subplot2grid(gridsize, (2, 0))
ax3 = plt.subplot2grid(gridsize, (2, 1))

# %%
# nun stellen wir die Abstände der "Ticks" auf der X-Achse ein
import numpy as np
monatstage = list(range(1,32))
# print(monatstage)
messwerte = [2,4,3,4,5,3,2,6,3,6,4,2,6,3,7,4,6,7,2,1,4,5,0,4,6,7,6,6,7,3,4]
plt.plot(monatstage, messwerte, "--m")
plt.xlabel("Tag des Monats")
plt.ylabel("Sonnenstunden")
plt.xticks(np.linspace(0, 30, 6,endpoint=True))
plt.show()

# %%
# Beispiel für plots mit besonderer Art der Darstellung
import pandas as pd
monatstage = list(range(1,9))
messwerte = [14,4,16,4,5,9,12,7]

#Nutzen von xkcd() für eine skizzenhafte Darstellung des Diagrams 
plt.xkcd(scale=5, length=400) 
plt.bar(monatstage, messwerte)
plt.ylabel('Umsatzsteigerung (%)') 
plt.xticks(rotation=-15) # wir drehen die Beschriftung an der x-Achse ein wenig
plt.figure(figsize=(10,8)) 
plt.show()

# %%
# Beispiel für das Erstellen einer Heatmap
import numpy as np
# hier werden für dieses Beispiel Zufallszahlen in einer 8x8 Matrix erzeugt
data = np.random.random((8, 8))
# wir nutzen die Funktion imshow(), um eine Heatmap zu erstellen
plt.imshow(data, cmap='cool', interpolation='nearest')
plt.show()

# %%
# Arbeiten mit seaborn
# seaborn ist eine Bibliothek für das erstellen von Grafiken für statistische Auswerungen
# viele Beispiele und ausfühliche Informationen zu seaborn findet man unter:
# https://seaborn.pydata.org/introduction.html
# Die folgenden Code-Beispiele wurden von https://seaborn.pydata.org/introduction.html übernommen.
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %%
# Ein weiteres Beispiel aus der Bibliothek seaborn zeigt, dass wenige Zeilen Code notwendig sind, 
# um kompliziert wirkende plots zu erstellen.
# Die folgenden Code-Beispiele wurden von https://seaborn.pydata.org/introduction.html übernommen.

dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)

# %%
# Ein weiteres Beispiel aus der Bibliothek seaborn zeigt, dass wenige Zeilen Code notwendig sind, 
# um kompliziert wirkende plots zu erstellen.
# Die folgenden Code-Beispiele wurden von https://seaborn.pydata.org/introduction.html übernommen.

penguins = sns.load_dataset("penguins")
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %% [markdown]
# eine umfangreiche Übersicht weiterer Arten von plots finden Sie unter folgendem Link:
# https://matplotlib.org/stable/gallery/
